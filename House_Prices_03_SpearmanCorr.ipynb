# %%
import pandas as pd

# %%
train_data = pd.read_csv('C:/Users/Satellite/Documents/1.DATA SCIENCE/KAGGLE/House Prices/train.csv')
train_data.drop(columns='Id', inplace=True)
train_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
# 2       0      9    2008        WD         Normal     223500
# 3       0      2    2006        WD        Abnorml     140000
# 4       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
spearman_values = train_data.corr(method='spearman').loc['SalePrice'].sort_values(ascending = False).rename(index='SpearmanCorr')
data_columns = [x for x in spearman_values.index]

null_values_count = [len(train_data[train_data[x].isnull()==True]) for x in data_columns]
null_values_count = pd.Series(null_values_count, name='NullValues')

null_values_percent = [round((x / len(train_data))*100, 2) for x in null_values_count]
null_values_percent = pd.Series(null_values_percent, name='PercentNull')

spearman_corr = spearman_values.reset_index()

table_1 = pd.concat([spearman_corr, null_values_count, null_values_percent], axis=1).rename(columns={"index": "VariableName"})
table_1
# Out:
#      VariableName  SpearmanCorr  NullValues  PercentNull
# 0       SalePrice      1.000000           0         0.00
# 1     OverallQual      0.809829           0         0.00
# 2       GrLivArea      0.731310           0         0.00
# 3      GarageCars      0.690711           0         0.00
# 4       YearBuilt      0.652682           0         0.00
# 5      GarageArea      0.649379           0         0.00
# 6        FullBath      0.635957           0         0.00
# 7     TotalBsmtSF      0.602725           0         0.00
# 8     GarageYrBlt      0.593788          81         5.55
# 9        1stFlrSF      0.575408           0         0.00
# 10   YearRemodAdd      0.571159           0         0.00
# 11   TotRmsAbvGrd      0.532586           0         0.00
# 12     Fireplaces      0.519247           0         0.00
# 13    OpenPorchSF      0.477561           0         0.00
# 14        LotArea      0.456461           0         0.00
# 15     MasVnrArea      0.421309           8         0.55
# 16    LotFrontage      0.409076         259        17.74
# 17     WoodDeckSF      0.353802           0         0.00
# 18       HalfBath      0.343008           0         0.00
# 19     BsmtFinSF1      0.301871           0         0.00
# 20       2ndFlrSF      0.293598           0         0.00
# 21   BedroomAbvGr      0.234907           0         0.00
# 22   BsmtFullBath      0.225125           0         0.00
# 23      BsmtUnfSF      0.185197           0         0.00
# 24    ScreenPorch      0.100070           0         0.00
# 25         MoSold      0.069432           0         0.00
# 26      3SsnPorch      0.065440           0         0.00
# 27       PoolArea      0.058453           0         0.00
# 28     MSSubClass      0.007192           0         0.00
# 29   BsmtHalfBath     -0.012189           0         0.00
# 30         YrSold     -0.029899           0         0.00
# 31     BsmtFinSF2     -0.038806           0         0.00
# 32        MiscVal     -0.062727           0         0.00
# 33   LowQualFinSF     -0.067719           0         0.00
# 34    OverallCond     -0.129325           0         0.00
# 35   KitchenAbvGr     -0.164826           0         0.00
# 36  EnclosedPorch     -0.218394           0         0.00
