# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr

# %%
import matplotlib.pyplot as plt
import seaborn as sb
sb.set(style="whitegrid")

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 10, 8

# %%
train_data = pd.read_csv('C:/Users/Satellite/Documents/1.DATA SCIENCE/KAGGLE/House Prices/train.csv')
train_data.drop(columns='Id', inplace=True)
train_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %% [markdown]
# ## OverallQual

# %%
train_data['OverallQual'].value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
sb.countplot(train_data['OverallQual'])

# %%
sb.regplot(x='OverallQual', y='SalePrice', data=train_data, scatter=True)

# %%
spearmanr(train_data['OverallQual'], train_data['SalePrice'])
# Out:
# SpearmanrResult(correlation=0.8098285862017292, pvalue=0.0)

# %%
pearsonr(train_data['OverallQual'], train_data['SalePrice'])
# Out:
# (0.79098160058381, 2.185675268e-313)

# %%
sb.boxplot(x='OverallQual', y='SalePrice', data=train_data, palette='hls')

# %% [markdown]
# ## OverallCond

# %%
train_data['OverallCond'].value_counts()
# Out:
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64

# %%
sb.countplot(train_data['OverallCond'])

# %%
sb.regplot(x='OverallCond', y='SalePrice', data=train_data, scatter=True)

# %%
spearmanr(train_data['OverallCond'], train_data['SalePrice'])
# Out:
# SpearmanrResult(correlation=-0.12932494660061317, pvalue=7.118552262128728e-07)

# %%
spearmanr(train_data['OverallCond'], train_data['OverallQual'])
# Out:
# SpearmanrResult(correlation=-0.17752065840995482, pvalue=8.398835320074494e-12)

# %%
sb.boxplot(x='OverallCond', y='SalePrice', data=train_data, palette='hls')

# %% [markdown]
# ### In the case of the "OverallCond" variable, the best alternative is to treat it as categorical and convert it to dummy variables.
